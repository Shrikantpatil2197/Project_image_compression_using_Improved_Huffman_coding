# %%
from time import sleep
import heapq
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image as im 
from termcolor import colored
import math

class HuffmanCoding:
    def __init__(self, path):
        self.path = path
        self.heap = []
        self.codes = {}
        self.reverse_mapping = {}

    class HeapNode:
        def __init__(self, char, freq):
            self.char = char
            self.freq = freq
            self.left = None
            self.right = None

        def __lt__(self, other):
            return self.freq < other.freq

        def __eq__(self, other):
            if(other == None):
                return False
            if(not isinstance(other, HeapNode)):
                return False
            return self.freq == other.freq

# functions for compression:

    def make_frequency_dict(self, o_image):
        frequency = {}
        for character in o_image:
            if not character in frequency:
                frequency[character] = 0
            frequency[character] += 1
#         print(colored('frequency of different pixels in the image:','red', attrs=['bold']))
#         print(frequency)
        return frequency

    def make_heap(self, frequency):
        for key in frequency:
            node = self.HeapNode(key, frequency[key])
            heapq.heappush(self.heap, node)
#         print(self.heap)

    def merge_nodes(self):
        while(len(self.heap)>1):
            node1 = heapq.heappop(self.heap)
            node2 = heapq.heappop(self.heap)
            merged = self.HeapNode(None, node1.freq + node2.freq)
            merged.left = node1
            merged.right = node2

            heapq.heappush(self.heap, merged)


    def make_codes_helper(self, root, current_code):
        if(root == None):
            return

        if(root.char != None):
            self.codes[root.char] = current_code
            self.reverse_mapping[current_code] = root.char
            return

        self.make_codes_helper(root.left, current_code + "0")
        self.make_codes_helper(root.right, current_code + "1")


    def make_codes(self):
        root = heapq.heappop(self.heap)
        current_code = ""
        self.make_codes_helper(root, current_code)


    def get_encoded_o_image(self, o_image):
        encoded_o_image = ""
        for character in o_image:
            encoded_o_image += self.codes[character]
#         print(encoded_o_image)
        return encoded_o_image


    def pad_encoded_o_image(self, encoded_o_image):
        extra_padding = 8 - len(encoded_o_image) % 8
        for i in range(extra_padding):
            encoded_o_image += "0"

        padded_info = "{0:08b}".format(extra_padding)
        encoded_o_image = padded_info + encoded_o_image
        return encoded_o_image


    def get_byte_array(self, padded_encoded_o_image):
        if(len(padded_encoded_o_image) % 8 != 0):
            print("Encoded o_image not padded properly")
            exit(0)

        b = bytearray()
        for i in range(0, len(padded_encoded_o_image), 8):
            byte = padded_encoded_o_image[i:i+8]
            b.append(int(byte, 2))
#         print(b)
        return b


    def compress(self):
        filename, file_extension = os.path.splitext(self.path)
        output_path = filename + ".bin"

        with open(output_path, 'wb') as output:
            img = cv2.imread(path,0)
            o_image = img.flatten()

            frequency = self.make_frequency_dict(o_image)
            self.make_heap(frequency)
            self.merge_nodes()
            self.make_codes()
#             print(colored('\nEncoded dictionary:','red', attrs=['bold']))
#             print(self.codes)
            encoded_o_image = self.get_encoded_o_image(o_image)
            padded_encoded_o_image = self.pad_encoded_o_image(encoded_o_image)
            b = self.get_byte_array(padded_encoded_o_image)
            output.write(bytes(b))

#         print(colored("\nCompressed!",'green',attrs=['bold']))
        return output_path

#  functions for decompression: 
    def remove_padding(self, padded_encoded_o_image):
        padded_info = padded_encoded_o_image[:8]
        extra_padding = int(padded_info, 2)

        padded_encoded_o_image = padded_encoded_o_image[8:] 
        encoded_o_image = padded_encoded_o_image[:-1*extra_padding]
        encoded_o_image = str(encoded_o_image)
        return encoded_o_image

    def decode_o_image(self, encoded_o_image):
        current_code = ""
        decoded_o_image = []
        
        for bit in encoded_o_image:
            current_code += bit
            if(current_code in self.reverse_mapping):
                character = self.reverse_mapping[current_code]
                decoded_o_image.append(character)
                current_code = ""
        return decoded_o_image


    def decompress(self, input_path):
        filename, file_extension = os.path.splitext(self.path)
        output_path = filename + "_decompressed" + ".bmp"

        with open(input_path, 'rb') as file, open(output_path, 'wb') as output:
            bit_string = ""

            byte = file.read(1)
            while(len(byte) > 0):
                byte = ord(byte)
                bits = bin(byte)[2:].rjust(8, '0')
                bit_string += bits
                byte = file.read(1)

            encoded_o_image = self.remove_padding(bit_string)
            img = cv2.imread(path,0)
            decompressed_o_image = self.decode_o_image(encoded_o_image) 
            dec_o_image = [i if i is not None else 0 for i in decompressed_o_image]
            out = np.array(dec_o_image)
            out_array = np.reshape(out,img.shape)
#             print(colored('Decoded image pixel values:','red',attrs=['bold']))
#             print(out_array)
            output_img = im.fromarray(out_array.astype(np.uint8))
            output_img.save(output)
#         print(colored("\nDecompressed!",'green',attrs=['bold']))
        return output_path
    

input_path = input("Enter image name that is to be compressed:\n")
input_extension = input('Enter extention of image that is to be compressed:eg.jpg or.png or .jpeg\n')

img = cv2.imread(input_path + input_extension,0)
print(img.shape)
plt.imshow(img,'gray')
plt.title('input image')
plt.show()
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        if (img[i][j] % 10 <= 5):
            img[i][j] = img[i][j] - img[i][j] % 10
        if (img[i][j] % 10 > 5):
            img[i][j] = img[i][j] + (10 - img[i][j] % 10)
# print(colored('input_image pixel values:','red', attrs=['bold']))
# print(img,'\n')

####Coventional method
# print(colored("Coventional method!",'magenta', attrs=['bold']))
# out_img = im.fromarray(img)
# out_img.save(input_path + ".bmp")
# in_img_size = os.stat(input_path  + ".bmp").st_size
# plt.imshow(img,'gray')
# plt.show()
# print(colored('input_image size in bytes:','red', attrs=['bold']))
# print(os.stat(input_path + ".bmp").st_size,'bytes')
# path = input_path  +  ".bmp"

# h = HuffmanCoding(path)
# output_path = h.compress()
# # print(colored("Compressed file path is:",'red', attrs=['bold']))
# # print(output_path)
# print(colored("compressed_image size in bytes:",'red', attrs=['bold']))
# print(os.stat(output_path).st_size,'bytes')


# decom_path = h.decompress(output_path)
# print(colored("Decompressed file path: ",'red', attrs=['bold']))
# print(decom_path)
# print(colored("decoded_image size in bytes:",'red', attrs=['bold']))
# print(os.stat(decom_path).st_size,'bytes')
# decoded_image = cv2.imread(decom_path)
# plt.imshow(decoded_image,'gray')
# plt.title('Decoded or reconstructed image:')
# plt.show()

###Proposed Method

windowsize_r = [342,171,114,57,38]
no_of_img_blocks = []
compression_ratio = []
for k in windowsize_r:
#     print(colored("proposed method!",'magenta', attrs=['bold']))
    # print('input image size:',img.shape)
    # sleep(0.1)
    # windowsize_r = int(input('decide window size besed on input size:'))
    B = img.shape[0]/k
    no_of_img_blocks.append(B)
    print(colored(f'Windowsize: {k}','magenta', attrs=['bold']))
    print(colored(f'no_of_img_blocks: {B}','magenta', attrs=['bold']))
    image_all = []
    for r in range(0,img.shape[0], k):
            window = img[r:r+k,:]
            image_all.append(window)
    input_img_size = 0
    comp_img_size = 0
    n = int(img.shape[0]/k)
    for i in range(n):
        output_img = im.fromarray(image_all[i])
        output_img.save(input_path + f"{i}" + ".bmp")
    #     print(colored(f'input_image {i} size in bytes:','red', attrs=['bold']))
    #     print(os.stat(input_path + f"{i}" + ".bmp").st_size,'bytes\n')
        input_img_size += os.stat(input_path + f"{i}" + ".bmp").st_size
    #     image = cv2.imread(input_path + f"{i}" + ".bmp",0)
    #     plt.imshow(image, cmap= 'gray')
    #     print(colored(f"\nInput image {i} that is to be compressed:",'red', attrs=['bold']))
    #     plt.show()

        path = input_path + f"{i}" +  ".bmp"

        h = HuffmanCoding(path)
        output_path = h.compress()
    #     print(colored("Compressed file path is:",'red', attrs=['bold']))
    #     print(output_path)
    #     print(colored("compressed_image size in bytes:",'red', attrs=['bold']))
    #     print(os.stat(output_path).st_size,'bytes\n')
        comp_img_size += os.stat(output_path).st_size

        decom_path = h.decompress(output_path)
    #     print(colored("Decompressed file path: ",'red', attrs=['bold']))
    #     print(decom_path)
    #     print(colored("decoded_image size in bytes:",'red', attrs=['bold']))
    #     print(os.stat(decom_path).st_size,'bytes')
        decoded_image = cv2.imread(decom_path)
    #     plt.imshow(decoded_image,'gray')
    #     plt.title(f'Decoded or reconstructed image:{input_path}{i}.bmp')
    #     plt.show()
        if i==0:
            img_back = decoded_image
        if (i<n) and i!=0 :
            img_back = np.vstack((img_back,decoded_image))
    print(colored('complete deconstructed image by proposed method :','red', attrs=['bold']))        
    plt.imshow(img_back,'gray')
    plt.show()
    print(colored('input_img_size:','red', attrs=['bold']))
    print(input_img_size,'bytes')
    print(colored('comp_img_size:','red', attrs=['bold']))
    print(comp_img_size,'bytes')
    print(colored('compression ratio:','red', attrs=['bold']))
    c = input_img_size/comp_img_size
    compression_ratio.append(c)
    print(c)
    print(colored('done!','green', attrs=['bold']))
print(compression_ratio)
print('\tcompression_ratio comparision:\n')
x = no_of_img_blocks
y = compression_ratio
low = min(y)
high = max(y)
plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
x_pos = [i for i in range(len(x))]
plt.bar(x_pos, y, color='green')
plt.xlabel('<------------------no_of_img_blocks----------------->')
plt.ylabel('<------------------compression ratio achieved----------------->')
plt.title('compression ratio achieved vs no_of_img_blocks')
plt.xticks(x_pos,x)
plt.show()
# Out:
# Enter image name that is to be compressed:
# messi5
# Enter extention of image that is to be compressed:eg.jpg or.png or .jpeg
# .jpg
# (342, 548)
# Windowsize: 342
# no_of_img_blocks: 1.0
# complete deconstructed image by proposed method :
# input_img_size:
# 188494 bytes
# comp_img_size:
# 96814 bytes
# compression ratio:
# 1.946970479476109
# done!
# Windowsize: 171
# no_of_img_blocks: 2.0
# complete deconstructed image by proposed method :
# input_img_size:
# 189572 bytes
# comp_img_size:
# 92479 bytes
# compression ratio:
# 2.049892408006142
# done!
# Windowsize: 114
# no_of_img_blocks: 3.0
# complete deconstructed image by proposed method :
# input_img_size:
# 190650 bytes
# comp_img_size:
# 91108 bytes
# compression ratio:
# 2.092571453659393
# done!
# Windowsize: 57
# no_of_img_blocks: 6.0
# complete deconstructed image by proposed method :
# input_img_size:
# 193884 bytes
# comp_img_size:
# 87993 bytes
# compression ratio:
# 2.203402543384133
# done!
# Windowsize: 38
# no_of_img_blocks: 9.0
# complete deconstructed image by proposed method :
# input_img_size:
# 197118 bytes
# comp_img_size:
# 86268 bytes
# compression ratio:
# 2.2849492279872026
# done!
# [1.946970479476109, 2.049892408006142, 2.092571453659393, 2.203402543384133, 2.2849492279872026]
# 	compression_ratio comparision:
